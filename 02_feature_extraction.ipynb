# %%
import os
import numpy as np
from PIL import Image
from tqdm import tqdm
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from monai.networks.nets import densenet121
from monai.transforms import Compose, Resize, ScaleIntensity

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class MammogramDataset(Dataset):
    def __init__(self, image_dir):
        self.image_dir = image_dir
        self.image_filenames = [f for f in sorted(os.listdir(image_dir)) if f.endswith((".png", ".jpg"))]
        self.transform = Compose([
            Resize((224, 224)),
            ScaleIntensity(),
        ])


    def __len__(self):
        return len(self.image_filenames)

    def __getitem__(self, idx):
        img_path = os.path.join(self.image_dir, self.image_filenames[idx])
        img = Image.open(img_path).convert("L")  # grayscale
        img = np.array(img) / 255.0
        img = np.expand_dims(img, axis=0)  # Ensure shape is (1, H, W)
        img = self.transform(img)
        return img.float(), self.image_filenames[idx]

# %%
# Load MONAI DenseNet121 pretrained on medical images
model = densenet121(spatial_dims=2, in_channels=1, out_channels=2, pretrained=True)
model.class_layers = torch.nn.Identity()  # remove final classifier layer to get features
model = model.to(device)
model.eval()

# %%
# Feature extraction
image_folder = "Path_To_Your_Mammogram_Images"  # Update this path
dataset = MammogramDataset(image_folder)
loader = DataLoader(dataset, batch_size=16, shuffle=False)

features = []
filenames = []

with torch.no_grad():
    for imgs, names in tqdm(loader):
        imgs = imgs.to(device)
        feats = model(imgs)
        features.append(feats.cpu().numpy())
        filenames.extend(names)

features = np.concatenate(features, axis=0)
np.save("Directory_path/features_monai_densenet121.npy", features) # Update this path
np.save("Directory_path/filenames_monai_densenet121.npy", filenames) # Update this path
print("✅ Feature extraction done and saved.")
